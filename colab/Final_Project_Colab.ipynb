# %%
# !pip install flask pyngrok transformers torch torchvision sentence-transformers pillow

# %%
# !pip install pyngrok
from pyngrok import ngrok
ngrok.set_auth_token("INSERT API KEY")

# %%
import sys
sys.path.insert(0, '/content')

from classifier import load_classifier, classify_image, get_class_names
from rag import load_rag, _retrieve, _answer

# %%
import torch
print(torch.cuda.is_available())  # should print True
# Out:
# True

# %%
import threading
from pyngrok import ngrok
from flask import Flask

ngrok.set_auth_token("INSERT API KEY")

exec(open('/content/app.py').read())

thread = threading.Thread(target=lambda: app.run(port=5000))
thread.start()

public_url = ngrok.connect(5000)
print(public_url)
# Out:
# loading models...
# loading embedding model...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# computing embeddings...
# gpu detected, loading phi-2...
# Loading weights:   0%|          | 0/453 [00:00<?, ?it/s]
# ready on http://localhost:5000
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [26/Apr/2026 20:19:03] "GET / HTTP/1.1" 200 -
# ...

# %%
from pyngrok import ngrok
ngrok.set_auth_token("INSERT API KEY")
public_url = ngrok.connect(5000)
print(public_url)
# Out:
# NgrokTunnel: "https://antarctic-chevron-promoter.ngrok-free.dev" -> "http://localhost:5000"
